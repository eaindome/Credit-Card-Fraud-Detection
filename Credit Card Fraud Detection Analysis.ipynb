# %% [markdown]
# ## Credit Card Fraud Detection

# %% [markdown]
# #### Work Flow
# Credit Card Data ---> Data pre processing ---> Data Analysis ---> Train Test Split ---> Logistic Regression Model ---> Evaluation

# %% [markdown]
# ### Modules/Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Credit Card Data

# %%
# loading the dataset
creditcard = pd.read_csv('creditcard.csv')
creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# checkingt the size of the data
creditcard.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Data Pre-processing

# %%
# checking for missing values
creditcard.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# checking the data types
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# ### Data Analysis

# %%
# checking the statistical information
creditcard.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# distribution of legit transactions and fraudulent transactions
creditcard['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 0 - Normal transaction
# 1 - Fraudulent transaction
# The data ishighly unbalanced. Reason being that the amount of data for normal transaction is more than that for fraudulent transaction, thus when fed into our machine learning model, it's going to be biased towards normal transaction and thus we cannot predict accurately any fraudulent transaction

# %%
# separating the data for more analysis
legit = creditcard[creditcard.Class == 0]
fraud = creditcard[creditcard.Class == 1]

# %%
# checking the size of the separated data
legit_shape = legit.shape
fraud_shape = fraud.shape
print(f"Size of normal transaction: {legit_shape}")
print(f"Size of fraudulent transaction: {fraud_shape}")
# Out:
# Size of normal transaction: (284315, 31)
# Size of fraudulent transaction: (492, 31)

# %%
# statistical measure of the data
# legit
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# fraud
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the value for both transaction
creditcard.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# ##### Number of Fraudulent Transactions -> 492

# %%
# sample 492 random data
legit_sample = legit.sample(n=492)

# %% [markdown]
# ##### Concatenating two dataframes

# %%
# concatenate 2 dataframes
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
# check the first five rows
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 264499  161458.0 -0.740109  1.766555 -0.683117  3.176792  3.095678  4.739461
# 250968  155148.0 -0.328250  0.836647 -1.783849 -1.640771  3.989082  2.952116
# 30184    35814.0 -0.196671 -0.067990  2.079449 -0.983374 -0.600528  0.544679
# 270545  164132.0 -1.804062  0.585676  0.136439 -2.228741 -1.291037 -0.356862
# 42817    41259.0  1.190232  0.283568  0.107623  0.994900  0.117527 -0.273007
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 264499  0.143650  0.894376 -1.690170  ... -0.179924 -0.462455  0.154498
# 250968  1.563025  0.260346 -0.773841  ...  0.324035  1.129778 -0.626787
# 30184  -0.477525  0.061920 -1.125595  ...  0.513537  1.596911 -0.243516
# 270545 -0.949186  1.251502 -1.427569  ...  0.566126  1.131402 -0.203957
# 42817   0.192243 -0.105199 -0.074866  ...  0.048758  0.206112 -0.136618
#
#              V24       V25       V26       V27       V28  Amount  Class
# 264499  0.647705 -0.983848 -0.061035 -0.654681 -0.212150    0.75      0
# 250968  0.774617  1.017503 -0.121418 -0.194330 -0.142987   13.83      0
# 30184  -0.246040 -0.483561  0.014363 -0.098892 -0.086810   11.00      0
# 270545 -0.285265  0.053134 -0.202753 -0.469931 -0.160964   39.95      0
# 42817  -0.259047  0.672821 -0.280123  0.029460  0.017689   23.32      0
#
# [5 rows x 31 columns]

# %%
# checking the distribution of data in the new dataset
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
# comparing the values for both transaction
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97258.563008  0.051312 -0.002064 -0.010246  0.027133  0.068990
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.073331  0.000895 -0.019338 -0.011531  ...  0.000797 -0.004503
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.011250 -0.036938  0.016315 -0.012527 -0.011764 -0.023400  0.003369
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       83.542967
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Train Test Split

# %%
# splitting the data into Features and Target
X = new_dataset.drop(columns='Class', axis=1)
y = new_dataset['Class']

# %%
# checking X
X.head(3)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 264499  161458.0 -0.740109  1.766555 -0.683117  3.176792  3.095678  4.739461
# 250968  155148.0 -0.328250  0.836647 -1.783849 -1.640771  3.989082  2.952116
# 30184    35814.0 -0.196671 -0.067990  2.079449 -0.983374 -0.600528  0.544679
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 264499  0.143650  0.894376 -1.690170  ...  0.285949 -0.179924 -0.462455
# 250968  1.563025  0.260346 -0.773841  ... -0.000724  0.324035  1.129778
# 30184  -0.477525  0.061920 -1.125595  ...  0.298909  0.513537  1.596911
#
#              V23       V24       V25       V26       V27       V28  Amount
# 264499  0.154498  0.647705 -0.983848 -0.061035 -0.654681 -0.212150    0.75
# 250968 -0.626787  0.774617  1.017503 -0.121418 -0.194330 -0.142987   13.83
# 30184  -0.243516 -0.246040 -0.483561  0.014363 -0.098892 -0.086810   11.00
#
# [3 rows x 30 columns]

# %%
# checking y
y.head(3)
# Out:
# 264499    0
# 250968    0
# 30184     0
# Name: Class, dtype: int64

# %% [markdown]
# ###### Training  data

# %%
# split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)

# check the size for the training data
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ##### Training the model

# %%
# model training
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ##### Accuracy Score

# %%
# accuracy score on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print(f"Accuracy score on training data: {training_data_accuracy*100}")
# Out:
# Accuracy score on training data: 94.0279542566709

# %%
# accuracy score on testing data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
print(f"Accuracy score on training data: {test_data_accuracy*100}")
# Out:
# Accuracy score on training data: 93.4010152284264
